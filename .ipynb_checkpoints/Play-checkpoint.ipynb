# %%
pip install chess
# Out:
# Requirement already satisfied: chess in c:\users\xiaji\anaconda3\lib\site-packages (1.9.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pygame
# Out:
# Requirement already satisfied: pygame in c:\users\xiaji\anaconda3\lib\site-packages (2.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pygame
import chess
import math
import random
import numpy as np
import chess.polyglot
import torch
import time
# Out:
# pygame 2.5.0 (SDL 2.28.0, Python 3.9.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
#initialise display
X = 800
Y = 800
scrn = pygame.display.set_mode((X, Y))
pygame.init()
reader = chess.polyglot.open_reader('baron30.bin')
#basic colours
WHITE = (255, 255, 255)
GREY = (128, 128, 128)
YELLOW = (204, 204, 0)
BLUE = (50, 255, 255)
BLACK = (0, 0, 0)


piece_width = 100
piece_height = 100

# Load and resize the piece images
pieces = {
    'p': pygame.transform.scale(pygame.image.load('images/b_p.png').convert(), (piece_width, piece_height)),
    'n': pygame.transform.scale(pygame.image.load('images/b_n.png').convert(), (piece_width, piece_height)),
    'b': pygame.transform.scale(pygame.image.load('images/b_b.png').convert(), (piece_width, piece_height)),
    'r': pygame.transform.scale(pygame.image.load('images/b_r.png').convert(), (piece_width, piece_height)),
    'q': pygame.transform.scale(pygame.image.load('images/b_q.png').convert(), (piece_width, piece_height)),
    'k': pygame.transform.scale(pygame.image.load('images/b_k.png').convert(), (piece_width, piece_height)),
    'P': pygame.transform.scale(pygame.image.load('images/w_p.png').convert(), (piece_width, piece_height)),
    'N': pygame.transform.scale(pygame.image.load('images/w_n.png').convert(), (piece_width, piece_height)),
    'B': pygame.transform.scale(pygame.image.load('images/w_b.png').convert(), (piece_width, piece_height)),
    'R': pygame.transform.scale(pygame.image.load('images/w_r.png').convert(), (piece_width, piece_height)),
    'Q': pygame.transform.scale(pygame.image.load('images/w_q.png').convert(), (piece_width, piece_height)),
    'K': pygame.transform.scale(pygame.image.load('images/w_k.png').convert(), (piece_width, piece_height)),
}

def update(scrn,board):
    '''
    updates the screen basis the board class
    '''
    
    for i in range(64):
        piece = board.piece_at(i)
        if piece == None:
            pass
        else:
            scrn.blit(pieces[str(piece)],((i%8)*100,700-(i//8)*100))
    
    for i in range(7):
        i=i+1
        pygame.draw.line(scrn,WHITE,(0,i*100),(800,i*100))
        pygame.draw.line(scrn,WHITE,(i*100,0),(i*100,800))

    pygame.display.flip()

# %%
def main(BOARD):

    scrn.fill(BLACK)
    pygame.display.set_caption('Chess')
    index_moves = []

    status = True
    while (status):
        #update screen
        update(scrn,BOARD)

        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                status = False

            if event.type == pygame.MOUSEBUTTONDOWN:
                scrn.fill(BLACK)
                pos = pygame.mouse.get_pos()
                square = (math.floor(pos[0]/100),math.floor(pos[1]/100))
                index = (7-square[1])*8+(square[0])
                if index in index_moves: 
                    
                    move = moves[index_moves.index(index)]
                    
                    BOARD.push(move)
                    index=None
                    index_moves = []
                else:
                    #check the square that is clicked
                    piece = BOARD.piece_at(index)
                    #if empty pass
                    if piece == None:
                        
                        pass
                    else:
                        all_moves = list(BOARD.legal_moves)
                        moves = []
                        for m in all_moves:
                            if m.from_square == index:                
                                moves.append(m)
                                t = m.to_square
                                TX1 = 100*(t%8)
                                TY1 = 100*(7-t//8)
                                pygame.draw.rect(scrn,BLUE,pygame.Rect(TX1,TY1,100,100),5)
                        
                        index_moves = [a.to_square for a in moves]
        if BOARD.outcome() != None:
            print(BOARD.outcome())
            status = False
            print(BOARD)
    pygame.quit()

def main_one_agent(BOARD,agent,agent_color):
    scrn.fill(BLACK)
    #name window
    pygame.display.set_caption('Chess')
    index_moves = []
    subtree = [[]]
    status = True
    while (status):
        update(scrn,BOARD)  
        if BOARD.turn==agent_color:
            start_time = time.time()
            tree = [[[BOARD, [0], eval_board(BOARD), 1]]]
            move, layers = agent(tree,subtree)
            BOARD.push(move)
            scrn.fill(BLACK)
            print("time used:", time.time()-start_time, "seconds")
        else:

            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    status = False
                if event.type == pygame.MOUSEBUTTONDOWN:
                    scrn.fill(BLACK)
                    pos = pygame.mouse.get_pos()
                    square = (math.floor(pos[0]/100),math.floor(pos[1]/100))
                    index = (7-square[1])*8+(square[0])
                    if index in index_moves: 
                        
                        move = moves[index_moves.index(index)]
                        #print(BOARD)
                        #print(move)
                        BOARD.push(move)
                        index=None
                        index_moves = []
                    else:                   
                        piece = BOARD.piece_at(index)                    
                        if piece == None:
                            pass
                        else:

                            all_moves = list(BOARD.legal_moves)
                            moves = []
                            for m in all_moves:
                                if m.from_square == index:          
                                    moves.append(m)
                                    t = m.to_square
                                    TX1 = 100*(t%8)
                                    TY1 = 100*(7-t//8)
                                    pygame.draw.rect(scrn,BLUE,pygame.Rect(TX1,TY1,100,100),5)
                            #print(moves)
                            index_moves = [a.to_square for a in moves]
        if BOARD.outcome() != None:
            print(BOARD.outcome())
            status = False
            print(BOARD)
    pygame.quit()

# %%
def board_to_tensor(board):
    tensor = np.zeros((1,15, 8, 8), dtype=np.float32)
    values = [1, 3, 3, 5, 9, 20]
    piece_map = board.piece_map()
    for square, piece in piece_map.items():
        piece_type = piece.piece_type
        color = (1 if piece.color else -1)
        piece_value = values[piece_type-1] * color
        layer = int(piece_type-1 + 3*(1+color))
        tensor[0,layer, chess.square_rank(square), chess.square_file(square)] = piece_value
        valid_squares = list(board.attacks(square))
        for s in valid_squares:
            tensor[0,layer, chess.square_rank(s), chess.square_file(s)] += 0.1*color
    turn = (1 if board.turn else -1)
    tensor[0, 12, 0, 0] = (0.5 if board.has_kingside_castling_rights(board.turn) else 0)
    tensor[0, 12, -1, 0] = (-0.5 if board.has_kingside_castling_rights(board.turn==False) else 0)
    tensor[0, 12, 0, -1] = (0.5 if board.has_queenside_castling_rights(board.turn) else 0)
    tensor[0, 12, -1, -1] = (-0.5 if board.has_queenside_castling_rights(board.turn==False) else 0)
    tensor[0, 13, :, :] = turn/640
    if board.is_checkmate():
        tensor[0, 14, :, :] = -turn
    return torch.from_numpy(tensor)

def fen_to_tensor(fen):
    board = chess.Board(fen)
    return(board_to_tensor(board))

# %%
scoring= {'p': -1,
          'n': -3,
          'b': -3,
          'r': -5,
          'q': -9,
          'k': -20,
          'P': 1,
          'N': 3,
          'B': 3,
          'R': 5,
          'Q': 9,
          'K': 20,
          }
def eval_space(BOARD):
    no_moves = len(list(BOARD.legal_moves))
    value = (no_moves/(20+no_moves))*2    
    if BOARD.turn == True:
        return value
    else:
        return -value
def eval_board(BOARD):
    #will be replaced by a deep network
    tensor = board_to_tensor(BOARD)[0]
    score = 0
    pieces = BOARD.piece_map()
    if BOARD.is_checkmate() and BOARD.turn == True:
        return(-1000)
    if BOARD.is_checkmate() and BOARD.turn == False:
        return(1000)
    if BOARD.is_stalemate():
        return(0)
    if BOARD.is_insufficient_material():
        return(0)
    if BOARD.has_insufficient_material(BOARD.turn):
        return(-100)
    if BOARD.has_insufficient_material(BOARD.turn == False):
        return(100)
    
    return int(torch.sum(tensor).item()*100)/100
def stable_eval(b):
    value = eval_board(b)
    m = 0
    B = b.copy()
    moves = list(b.legal_moves)
    for move in moves:
        copy = b.copy()
        copy.push(move)
        v = eval_board(copy)
        a = np.abs(v-value)
        if (a>0.9) and (a > m) :
            m = a
            B = copy.copy()
    if m >=0.9:
        return(stable_eval(B))
    else:
        return(value)

# %%
#initialise chess board

b = chess.Board()

# %%
class Parameters:
    def __init__(self, risk, width, depth, agressivity):
        self.risk = risk
        self.width = width
        self.depth = depth
        self.agressivity = agressivity

# %%
def mini_max(tree, subtree, parameters, eval_board, color):
    #tree[layer,...]
    #layer[nodes,...]
    #initial tree = [[[chess.Board(), [], 0, 1]]]
    #node [board, position, value, fertile]
    #width : matrix : 
    #width[i][j] = number of fertile leafs that we keep after the pruning of layer i+1 using the result of layer i+j+1
    depth = parameters.depth
    
    moves = list(b.legal_moves)
    if len(moves) ==0:
        return(chess.Move.null(), [[]])
    else :
        opening_move = reader.get(b)
        if opening_move == None:
            pass
        else:
            return (opening_move.move, [[]])
        #sub, id = is_board_in_list(b, tree[-1])
        if False:
            print("recycle")
            layers = subtree(layers, id)
            depth = 4
            width = width[:-4]
        else:
            print("-------------")
            print("initial")
            print("initial board value = " + str(eval_board(b)))
            print(b)
            print("exploration stage")
            for i in range(depth):
                
                side = ((i%2 == 0)== color)  #if color == False, i ==0 : side = False
                print(side)
                print("growing")
                old, new = grow(tree[-1], eval_board, side)
                tree[-1] = old
                tree.append(new)
                if len(tree)>=0:
                    print("pruning")
                    tree = prun(tree, eval_board, parameters, side==False)
                    print("sterilizing")
                    tree[-1] = sterilize(tree[-2], tree[-1])
                print("exploration " + str((i+1)*100/depth) + " %")
            print("up propagating")
            best_move, l = up_propagate(tree[:-1], color==(depth%2==0), [])
            print("showing steps")
            print_steps(l)
            return(best_move, tree[2:])

# %%
#tree[layer,...]
#layer[nodes,...]
#initial tree = [[[chess.Board(), [0], 0, True]]]
#node [board, position, value, fertile]
#width[i][j] = number of fertile leafs that we keep after the pruning of layer i+1 using the result of layer i+j+1
def grow(leafs, eval_board, side):
    new_layer = []
    for k in range(len(leafs)):
        b = leafs[k][0]
        moves = list(b.legal_moves)
        temp = []
        if len(moves) !=0:
            for i in range(len(moves)):
                copy = b.copy()
                copy.push(moves[i])
                temp.append([copy, leafs[k][1]+ [i], eval_board(copy), 1])
            if side:
                leafs[k][2] = (max(temp, key=lambda x: x[2]))[2]
            else:
                leafs[k][2]= (min(temp, key=lambda x: x[2]))[2]
        new_layer +=temp
    return(leafs, new_layer)
def prun(tree, eval_board, parameters, side):
    tree_depth = len(tree)
    width = parameters.width
    risk = parameters.risk*10**(-(tree_depth-1)/parameters.depth)
    k = 0
    ancestor_depth = tree_depth-3 - 2*k # depth of the common ancestor
    pruned_layer = tree[-2]
    while ancestor_depth >=0:
        print("ancestor_depth = " + str(ancestor_depth))
        pruned_layer = prun_layer(pruned_layer, ancestor_depth, width[tree_depth-3][k], risk, side)
        k+=1
        ancestor_depth = tree_depth-3 - 2*k
    tree[-2] = pruned_layer
    return(tree)

def prun_layer(layer, depth, width, risk, side):
    #depth : depth of the ancestor
    layer = group_with_relatives(layer, depth)
    print("n_group = " + str(len(layer)))
    new_layer = []
    #print(layer[:3])
    print("width  = " + str(width))
    for l in layer:
        l= keep_best(l, width, risk, side)
        new_layer+=l  
    
    return(new_layer)
def keep_best(L, width, risk, side):
    #print("width  = " + str(width))
    #print("moves = " + str(len(L)))
    if len(L)<= width:
        return(L)
    else:     
        L.sort(key=lambda l: l[2], reverse=side)
        w2 = int((1-risk)*width)
        p = L[:w2]
        rest = L[w2:]
        l = len(rest)
        rate = np.exp(np.log(0.05)/l)
        weights = [rate ** i for i in range(l)]
        for r in rest:
            if r[3] !=-1:
                r[3] = 0
        selected_indices = random.choices(range(len(rest)), weights, k=width - w2)
        for idx in selected_indices:
            if rest[idx][3]!=-1:
                rest[idx][3] = 1
        new = p + rest
        for n in new:
            if n[3]==0:
                n[3] = -1
        return(new)
def sterilize(L1, L2):
    print("before pruning : " + str(len(L2)))
    print(sum(item[2] for item in L2) / len(L2))
    l1_dict = {str((l[1])) for l in L1 if l[3]!=1}
    result = [l for l in L2 if (str(l[1][:-1])) not in l1_dict]
    print("after pruning : " + str(len(result)))
    print(sum(item[2] for item in result) / len(result))
    return(result)
def up_propagate(tree, side, l):
    if len(tree)<=2:
        tree[-1].sort(key=lambda l: l[2], reverse=side)
        obj = tree[-1][0]
        l.append([obj])
        b = obj[0].copy()
        return(b.pop(), l)
    else:
        L = [l for l in tree[-1] if l[3] == 1]
        L = prun_layer(L, len(tree)-2, 1, 0, side)
        L2 = [l for l in L if l[3] == 1]             
        l.append(L2)
        dict_l2 = {str(l2[1][:-1]): l2[2] for l2 in L2}
        for l1 in tree[-2]:
            if str(l1[1]) in dict_l2:
                l1[2] = dict_l2[str(l1[1])]
        return(up_propagate(tree[:-1], side==False, l))
def print_steps(l):
    l.reverse()
    print(l)
    next_ = [0]
    for k in range(len(l)):
        P = True
        for e in l[k]:
            if e[1][:-1]==next_:
                next_ = e[1]
                print(e[0])
                print("value = " + str(e[2]))
                P = False
                continue
        if P:
            print("not found " + str(next_))
def group_with_relatives(L, depth):
    result = {}
    for l in L:
        prefix = l[1][:depth+1]
        if str(prefix) in result:
            result[str(prefix)].append(l)
        else:
            result[str(prefix)] = [l]
    return (list(result.values()))
def unique(L):
    unique_dict = {}
    for sublist in L:
        value = sublist[0].fen()
        if value not in unique_dict:
            unique_dict[value] = sublist
    unique_list = list(unique_dict.values())
    return unique_list

# %%
def play_min_maxN(tree, subtree):
    depth = 6
    risk = 0.3
    agressivity = 0.5
    width = [[16, 0, 0, 0, 0],[8, 0, 0, 0, 0],[8, 8, 0, 0, 0],[8, 8, 0, 0, 0],[10, 12, 8, 8, 3],[10, 12, 8, 8, 0],[5, 8, 7, 7, 0]]
    #
    parameters = Parameters(risk, width, depth, agressivity)
    color = False
    print(parameters.depth)
    return mini_max(tree, subtree, parameters, eval_board, color)

# %%
L = [[0,[0,1,2]],[0,[0,2,2]],[0,[0,2,7]],[0,[0,3,2]],[0,[0,3,8]]]
print(group_with_relatives(L, 1))
# Out:
# [[[0, [0, 1, 2]]], [[0, [0, 2, 2]], [0, [0, 2, 7]]], [[0, [0, 3, 2]], [0, [0, 3, 8]]]]

# %%
b = chess.Board()
main_one_agent(b,play_min_maxN,False)
# Out:
# 6
# time used: 0.0010259151458740234 seconds
# 6
# time used: 0.0020346641540527344 seconds
# 6
# -------------
# initial
# initial board value = 0.6
# r n b q k b . r
# p p p p . p p p
# . . . . p n . .
# . . . . . . . .
# . . . . P . . .
# . . . . . Q . .
# P P P P . P P P
# R N B . K B N R
# exploration stage
# False
# growing
# pruning
# sterilizing
# before pruning : 28
# 0.7178571428571432
# after pruning : 28
# 0.7178571428571432
# exploration 16.666666666666668 %
# True
# growing
# pruning
# ancestor_depth = 0
# n_group = 1
# width  = 16
# sterilizing
# before pruning : 1063
# 0.5860395108184381
# after pruning : 607
# 0.471383855024712
# exploration 33.333333333333336 %
# False
# growing
# pruning
# ancestor_depth = 1
# n_group = 16
# width  = 8
# sterilizing
# before pruning : 18014
# 0.5381286776951273
# after pruning : 3763
# 0.9028992824873759
# exploration 50.0 %
# True
# growing
# pruning
# ancestor_depth = 2
# n_group = 128
# width  = 8
# ancestor_depth = 0
# n_group = 1
# width  = 8
# sterilizing
# before pruning : 148048
# 0.6920972927699465
# after pruning : 244
# -1.099057377049181
# exploration 66.66666666666667 %
# False
# growing
# pruning
# ancestor_depth = 3
# n_group = 8
# width  = 8
# ancestor_depth = 1
# n_group = 2
# width  = 8
# sterilizing
# before pruning : 8045
# -0.11979241765071358
# after pruning : 492
# 1.1858130081300813
# exploration 83.33333333333333 %
# True
# growing
# pruning
# ancestor_depth = 4
# n_group = 15
# width  = 10
# ancestor_depth = 2
# n_group = 2
# width  = 12
# ancestor_depth = 0
# n_group = 1
# width  = 8
# sterilizing
# before pruning : 18045
# 0.3398459407037996
# after pruning : 250
# -1.8293599999999985
# exploration 100.0 %
# up propagating
# n_group = 3
# width  = 1
# n_group = 5
# width  = 1
# n_group = 2
# width  = 1
# n_group = 16
# width  = 1
# showing steps
# [[[Board('r1bqkb1r/pppp1ppp/2n1pn2/8/4P3/5Q2/PPPP1PPP/RNB1KBNR w KQkq - 4 4'), [0, 8], -0.69, 1]], [[Board('rnbqkbr1/pppp1ppp/4pn2/4P3/8/5Q2/PPPP1PPP/RNB1KBNR b KQq - 0 4'), [0, 0, 25], 0.9, 1], [Board('rnbqk2r/ppppbppp/4pn2/4P3/8/5Q2/PPPP1PPP/RNB1KBNR b KQkq - 0 4'), [0, 1, 25], 0.3, 1], [Board('rnbqk2r/pppp1ppp/3bpn2/4P3/8/5Q2/PPPP1PPP/RNB1KBNR b KQkq - 0 4'), [0, 2, 25], -0.49, 1], [Board('rnbqk2r/pppp1ppp/4pn2/2b5/3PP3/5Q2/PPP2PPP/RNB1KBNR b KQkq - 0 4'), [0, 3, 34], -0.39, 1], [Board('rnbqk2r/pppp1ppp/4pn2/8/1b2P3/5Q1N/PPPP1PPP/RNB1KB1R b KQkq - 5 4'), [0, 4, 14], 0.4, 1], [Board('rnbq1b1r/ppppkppp/4pn2/4P3/8/5Q2/PPPP1PPP/RNB1KBNR b KQ - 0 4'), [0, 6, 25], 1.5, 1], [Board('rnb1kb1r/ppppqppp/4pn2/4P3/8/5Q2/PPPP1PPP/RNB1KBNR b KQkq - 0 4'), [0, 7, 25], -0.19, 1], [Board('r1bqkb1r/pppp1ppp/2n1pn2/4P3/8/5Q2/PPPP1PPP/RNB1KBNR b KQkq - 0 4'), [0, 8, 25], -0.69, 1], [Board('r1bqkb1r/pppp1ppp/B3pn2/8/4P3/5Q2/PPPP1PPP/RNB1K1NR b KQkq - 0 4'), [0, 9, 16], 0.4, 1], [Board('rnbqkbnr/pppp1ppp/4p3/4P3/8/5Q2/PPPP1PPP/RNB1KBNR b KQkq - 0 4'), [0, 10, 26], 0.6, 1], [Board('rnbqkb1r/pppp1ppp/4p3/7Q/4P3/8/PPPP1PPP/RNB1KBNR b KQkq - 0 4'), [0, 11, 2], 2.69, 1], [Board('rnbqkb1r/pppp1ppp/4p3/8/4P1Q1/8/PPPP1PPP/RNB1KBNR b KQkq - 0 4'), [0, 13, 3], 2.99, 1], [Board('rnbqkb1r/pppp1ppp/4p3/8/4Q3/8/PPPP1PPP/RNB1KBNR b KQkq - 0 4'), [0, 14, 6], 2.5, 1], [Board('rnbqkb1r/1ppp1ppp/p3pn2/4P3/8/5Q2/PPPP1PPP/RNB1KBNR b KQkq - 0 4'), [0, 20, 25], 0.4, 1], [Board('rnbqkb1r/pppp1ppp/5n2/4p3/2B1P3/5Q2/PPPP1PPP/RNB1K1NR b KQkq - 1 4'), [0, 21, 18], -0.29, 1], [Board('rnbqkb1r/ppp2ppp/4pn2/1B1p4/4P3/5Q2/PPPP1PPP/RNB1K1NR b KQkq - 1 4'), [0, 24, 17], 0.0, 1]], [[Board('rnbqk2r/pppp1ppp/3bp3/8/4n3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 5'), [0, 2, 13, 11], -1.19, 1], [Board('rnbqk1nr/pppp1ppp/4p3/8/1b2P3/5Q1N/PPPP1PPP/RNB1KB1R w KQkq - 6 5'), [0, 4, 14, 7], 0.4, 1]], [[Board('rnbq1k1r/pppp1ppp/3bpn2/8/4P3/5Q2/PPPP1PPP/RNB1KBNR b KQ - 7 5'), [0, 2, 13, 2, 11], 0.0, 1], [Board('rnbq1rk1/pppp1ppp/3bpn2/8/4P3/5Q2/PPPP1PPP/RNB1KBNR b KQ - 7 5'), [0, 2, 13, 21, 11], -0.1, 1], [Board('rnbq3r/ppppkppp/3bpn2/8/4P3/5Q2/PPPP1PPP/RNB1KBNR b KQ - 7 5'), [0, 2, 13, 3, 11], -0.29, 1], [Board('rnbqk1r1/pppp1ppp/3bpn2/8/4P3/5Q2/PPPP1PPP/RNB1KBNR b KQq - 7 5'), [0, 2, 13, 0, 11], -0.5, 1], [Board('rnbqk1nr/pppp1ppp/4p3/8/1bB1P3/5Q1N/PPPP1PPP/RNB1K2R b KQkq - 7 5'), [0, 4, 14, 7, 20], 0.4, 1]], [[Board('rnbq1rk1/pppp1ppp/3bp3/8/3Pn3/8/PPP2PPP/RNBQKBNR w KQ - 0 6'), [0, 2, 13, 21, 26, 10], -1.89, 1], [Board('rnbq1k1r/pppp1ppp/3bp3/8/3Pn3/8/PPP2PPP/RNBQKBNR w KQ - 0 6'), [0, 2, 13, 2, 26, 13], -1.79, 1], [Board('r1bq1k1r/pppp1ppp/2nbpn2/8/4P3/2N5/PPPP1PPP/R1BQKBNR w KQ - 8 6'), [0, 2, 13, 2, 13, 6], -0.79, 1]]]
# r . b q k b . r
# p p p p . p p p
# . . n . p n . .
# . . . . . . . .
# . . . . P . . .
# . . . . . Q . .
# P P P P . P P P
# R N B . K B N R
# value = -0.69
# r . b q k b . r
# p p p p . p p p
# . . n . p n . .
# . . . . P . . .
# . . . . . . . .
# . . . . . Q . .
# P P P P . P P P
# R N B . K B N R
# value = -0.69
# not found [0, 8, 25]
# not found [0, 8, 25]
# not found [0, 8, 25]
# time used: 106.80169320106506 seconds

# %%
boards = [chess.Board()]*1000
start_time = time.time()
for b in boards:
    #a = stable_eval(b)
    a = eval_board(b)
print((time.time()-start_time))
# Out:
# 0.4954838752746582

# %%
"""class Tree:
    def __init__(self, eval_board, board=chess.Board(), position=[], value=0, fertile=True, depth = 0, leafs=[]):
        self.board = board
        self.position = position
        self.value = value
        self.fertile = fertile
        self.depth = depth
        self.leafs = leafs
        self.eval_board = eval_board
    # Instance method
    def grow(self):
        if self.leafs !=[]:
            for leaf in leaf:
                leaf = leaf.grow()
        else:
            if self.fertile:
                moves = list(self.board.legal_moves)
                L = []
                for k in range(len(moves)):
                    copy = self.board.copy()
                    copy.push(moves[k])
                    L.append(Tree(copy, position+[k], self.eval_board(copy), False, [], self.eval_board))
                L.sort(key=lambda l: l[2], reverse=side)
                self.leafs = L
    def 
    def maturate(self):
        if self.leafs !=[]:
            for leaf in leaf:
                leaf = leaf.maturate
        else:
            self.fertile = True
    def get(self, position):
        c = self.copy()
        for k in range(len(position)):
            c = c.leafs[position[k]]
        return(c)
    def replace(self, position, new):
        if position !=[]:
            index = position.pop(0)
            self.leafs[index].replace(position, new)
        else:
            self = new
    def cut(self, position):
        if position !=[]:
            index = position.pop(0)
            self.leafs[index].cut(position)
        else:
            self.fertile = False
            for leaf in self.leafs:
                leaf.cut([])
    def nodes(self, depth):
        l = []
        if self.depth < depth-1:
            for leaf in self.leafs:
                l=+leaf.nodes(depth)
            return(l)
        else:
            return(self.leafs)
    def pruning(self, width, depth):
        nodes = self.nodes(int(self.depth-2*depth))
        for node in nodes:
            node.prun_node(width)
    def prun_node(self, width):
        l = self.nodes(self.depth)
        L = []
        for e in l
            L.append(e.position, e.progressions)
"""
# Out:
# 'class Tree:\n    def __init__(self, eval_board, board=chess.Board(), position=[], value=0, fertile=True, depth = 0, leafs=[]):\n        self.board = board\n        self.position = position\n        self.value = value\n        self.fertile = fertile\n        self.depth = depth\n        self.leafs = leafs\n        self.eval_board = eval_board\n    # Instance method\n    def grow(self):\n        if self.leafs !=[]:\n            for leaf in leaf:\n                leaf = leaf.grow()\n        else:\n            if self.fertile:\n                moves = list(self.board.legal_moves)\n                L = []\n                for k in range(len(moves)):\n                    copy = self.board.copy()\n                    copy.push(moves[k])\n                    L.append(Tree(copy, position+[k], self.eval_board(copy), False, [], self.eval_board))\n                L.sort(key=lambda l: l[2], reverse=side)\n                self.leafs = L\n    def \n    def maturate(self):\n        if self.leafs !=[]:\n            for leaf in leaf:\n                leaf = leaf.maturate\n        else:\n            self.fertile = True\n    def get(self, position):\n        c = self.copy()\n        for k in range(len(position)):\n            c = c.leafs[position[k]]\n        return(c)\n    def replace(self, position, new):\n        if position !=[]:\n            index = position.pop(0)\n            self.leafs[index].replace(position, new)\n        else:\n            self = new\n    def cut(self, position):\n        if position !=[]:\n            index = position.pop(0)\n            self.leafs[index].cut(position)\n        else:\n            self.fertile = False\n            for leaf in self.leafs:\n                leaf.cut([])\n    def nodes(self, depth):\n        l = []\n        if self.depth < depth-1:\n            for leaf in self.leafs:\n                l=+leaf.nodes(depth)\n            return(l)\n        else:\n            return(self.leafs)\n    def pruning(self, width, depth):\n        nodes = self.nodes(int(self.depth-2*depth))\n        for node in nodes:\n            node.prun_node(width)\n    def prun_node(self, width):\n        l = self.nodes(self.depth)\n        L = []\n        for e in l\n            L.append(e.position, e.progressions)\n'

# %%
"""
def minimax(b, depth, width, tree, eval_board):
    layers = []
    layer = []
    print("layers stage")
    Moves = list(b.legal_moves)
   
    if len(Moves) ==0:
        return(chess.Move.null(), eval_board(b))
    else :
        opening_move = reader.get(b)
        if opening_move == None:
            pass
        else:
            return (opening_move.move, [[]])
        sub, id = is_board_in_list(b, tree[0])
        if sub:
            print("recycle")
            layers = subtree(layers, id)
            depth = 4
            width = width[:-4]
        else:
            print("-------------")
            print("initial")
            print("initial board value = " + str(eval_board(b)))
            print(b)
            Moves = random.sample(Moves, len(Moves))
            for k in range(len(Moves)):
                copy = b.copy()
                copy.push(Moves[k])
                layer.append([Moves[k], copy, eval_board(copy), str(k)+"_", "root"])
            layer = pruning(layer, width[0], False)
            layers.append(layer)
            dim = len(layers[-1])
    for l in range(depth-1):
        side = (l%2 == 0)
        layer = []
        for d in range(dim):
            b = layers[-1][d][1]
            moves = list(b.legal_moves)
            
            if len(moves) ==0:
                layer.append([chess.Move.null(), b, eval_board(b), str(d)+"_", layers[-1][d][3]])
            else :
                moves = random.sample(moves, len(moves))
                for k in range(len(moves)):
                    copy = b.copy()
                    copy.push(moves[k])
                    layer.append([moves[k], copy, eval_board(copy), str(d)+"_"+str(k), layers[-1][d][3]])
        layer = pruning(layer, width[l], side)
        dim = len(layer)
        layers.append(layer)
    opponent_best_moves = []
    best_response_moves = []
    print("final stage")
    for k in range(len(layer)):
        copy = layer[k][1].copy()
        previous = layer[k][3]
        opponent_best_moves.append(best_move(copy, eval_board, True) + [previous])
    #print(np.array(opponent_best_moves.shape))
    for k in range(len(opponent_best_moves)):
        copy = opponent_best_moves[k][0]
        previous = opponent_best_moves[k][2]
        best_response_moves.append(best_move(copy, eval_board, False) + [previous])
    print("unwrap stage")
    previous_index = min(range(len(best_response_moves)), key=lambda i: best_response_moves[i][1])
    worst_index = max(range(len(best_response_moves)), key=lambda i: best_response_moves[i][1])
    previous = best_response_moves[previous_index][2]
    worst = best_response_moves[worst_index][2]
    final_best_move = chess.Move.null()
    steps = []
    print("best")
    for l in range(depth):
        for element in layers[depth-l-1]:
            if element[3] == previous:
                if element[4] == "root":
                    final_best_move = element[0]
                previous = element[4]
                steps.append([element[1], element[2]])
    steps.reverse()
    for k in range(len(steps)):
        print(steps[k][0])
        print("board value = " + str(steps[k][1]))
    print(opponent_best_moves[previous_index][0])
    print("board value = " + str(opponent_best_moves[previous_index][1]))
    print(best_response_moves[previous_index][0])
    print("board value = " + str(best_response_moves[previous_index][1]))
    
    
    worst_move = chess.Move.null()
    steps = []
    print("worst")
    for l in range(depth):
        for element in layers[depth-l-1]:
            if element[3] == worst:
                if element[4] == "root":
                    worst_move = element[0]
                worst = element[4]
                steps.append([element[1], element[2]])
    steps.reverse()
    for k in range(len(steps)):
        print(steps[k][0])
        print("board value = " + str(steps[k][1]))
    print(opponent_best_moves[worst_index][0])
    print("board value = " + str(opponent_best_moves[worst_index][1]))
    print(best_response_moves[worst_index][0])
    print("board value = " + str(best_response_moves[worst_index][1]))    
    return(final_best_move, layers[2:])
            """
# Out:
# '\ndef minimax(b, depth, width, tree, eval_board):\n    layers = []\n    layer = []\n    print("layers stage")\n    Moves = list(b.legal_moves)\n   \n    if len(Moves) ==0:\n        return(chess.Move.null(), eval_board(b))\n    else :\n        opening_move = reader.get(b)\n        if opening_move == None:\n            pass\n        else:\n            return (opening_move.move, [[]])\n        sub, id = is_board_in_list(b, tree[0])\n        if sub:\n            print("recycle")\n            layers = subtree(layers, id)\n            depth = 4\n            width = width[:-4]\n        else:\n            print("-------------")\n            print("initial")\n            print("initial board value = " + str(eval_board(b)))\n            print(b)\n            Moves = random.sample(Moves, len(Moves))\n            for k in range(len(Moves)):\n                copy = b.copy()\n                copy.push(Moves[k])\n                layer.append([Moves[k], copy, eval_board(copy), str(k)+"_", "root"])\n            layer = pruning(layer, width[0], False)\n            layers.append(layer)\n            dim = len(layers[-1])\n    for l in range(depth-1):\n        side = (l%2 == 0)\n        layer = []\n        for d in range(dim):\n            b = layers[-1][d][1]\n            moves = list(b.legal_moves)\n            \n            if len(moves) ==0:\n                layer.append([chess.Move.null(), b, eval_board(b), str(d)+"_", layers[-1][d][3]])\n            else :\n                moves = random.sample(moves, len(moves))\n                for k in range(len(moves)):\n                    copy = b.copy()\n                    copy.push(moves[k])\n                    layer.append([moves[k], copy, eval_board(copy), str(d)+"_"+str(k), layers[-1][d][3]])\n        layer = pruning(layer, width[l], side)\n        dim = len(layer)\n        layers.append(layer)\n    opponent_best_moves = []\n    best_response_moves = []\n    print("final stage")\n    for k in range(len(layer)):\n        copy = layer[k][1].copy()\n        previous = layer[k][3]\n        opponent_best_moves.append(best_move(copy, eval_board, True) + [previous])\n    #print(np.array(opponent_best_moves.shape))\n    for k in range(len(opponent_best_moves)):\n        copy = opponent_best_moves[k][0]\n        previous = opponent_best_moves[k][2]\n        best_response_moves.append(best_move(copy, eval_board, False) + [previous])\n    print("unwrap stage")\n    previous_index = min(range(len(best_response_moves)), key=lambda i: best_response_moves[i][1])\n    worst_index = max(range(len(best_response_moves)), key=lambda i: best_response_moves[i][1])\n    previous = best_response_moves[previous_index][2]\n    worst = best_response_moves[worst_index][2]\n    final_best_move = chess.Move.null()\n    steps = []\n    print("best")\n    for l in range(depth):\n        for element in layers[depth-l-1]:\n            if element[3] == previous:\n                if element[4] == "root":\n                    final_best_move = element[0]\n                previous = element[4]\n                steps.append([element[1], element[2]])\n    steps.reverse()\n    for k in range(len(steps)):\n        print(steps[k][0])\n        print("board value = " + str(steps[k][1]))\n    print(opponent_best_moves[previous_index][0])\n    print("board value = " + str(opponent_best_moves[previous_index][1]))\n    print(best_response_moves[previous_index][0])\n    print("board value = " + str(best_response_moves[previous_index][1]))\n    \n    \n    worst_move = chess.Move.null()\n    steps = []\n    print("worst")\n    for l in range(depth):\n        for element in layers[depth-l-1]:\n            if element[3] == worst:\n                if element[4] == "root":\n                    worst_move = element[0]\n                worst = element[4]\n                steps.append([element[1], element[2]])\n    steps.reverse()\n    for k in range(len(steps)):\n        print(steps[k][0])\n        print("board value = " + str(steps[k][1]))\n    prin ...

# %%
"""def main_two_agent(BOARD,agent1,agent_color1,agent2):

    scrn.fill(BLACK)
    #name window
    pygame.display.set_caption('Chess')
    status = True
    while (status):
        #update screen
        update(scrn,BOARD)
        
        if BOARD.turn==agent_color1:
            BOARD.push(agent1(BOARD)[0])

        else:
            BOARD.push(agent2(BOARD)[0])

        scrn.fill(BLACK)
            
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                status = False
     
    # deactivates the pygame library
        if BOARD.outcome() != None:
            print(BOARD.outcome())
            status = False
            print(BOARD)
    pygame.quit()"""
# Out:
# "def main_two_agent(BOARD,agent1,agent_color1,agent2):\n\n    scrn.fill(BLACK)\n    #name window\n    pygame.display.set_caption('Chess')\n    status = True\n    while (status):\n        #update screen\n        update(scrn,BOARD)\n        \n        if BOARD.turn==agent_color1:\n            BOARD.push(agent1(BOARD)[0])\n\n        else:\n            BOARD.push(agent2(BOARD)[0])\n\n        scrn.fill(BLACK)\n            \n        for event in pygame.event.get():\n            if event.type == pygame.QUIT:\n                status = False\n     \n    # deactivates the pygame library\n        if BOARD.outcome() != None:\n            print(BOARD.outcome())\n            status = False\n            print(BOARD)\n    pygame.quit()"

# %%
"""def unique(L):
    unique_dict = {}
    for sublist in L:
        value = sublist[1].fen()
        if value not in unique_dict:
            unique_dict[value] = sublist
    unique_list = list(unique_dict.values())
    return unique_list
def pruning(moves, width, side):
    moves = unique(moves)
    w2 = width//2
    if len(moves) <= width:
        return moves
    else:
        moves.sort(key=lambda l: l[2], reverse=side)
        p = moves[:w2]
        rest = moves[w2:]
        l = len(rest)
        rate = np.exp(np.log(0.05)/l)
        weights = [rate ** i for i in range(l)]
        random_elements = random.choices(rest, weights=weights, k=width - w2)
        new = p + random_elements
        new = unique(new)
        new.sort(key=lambda l: l[2], reverse=side)
        return(new)
def score_move(b, eval_board):
    moves = list(b.legal_moves)
    if len(moves) ==0:
        return[chess.Move.null(), eval_board(b)]
    else :
        scored_moves = []
        for move in moves:
            copy = b.copy()
            copy.push(move)
            scored_moves.append([copy, eval_board(copy)])
    return(scored_move)
def best_move(b,evalboard, side):
    scored_moves = score_move(b, eval_board)
    if side:
        return(max(scored_moves, key=lambda x: x[1]))
    else:
        return(min(scored_moves, key=lambda x: x[1]))

def is_board_in_list(board, L):
    board_fen = board.fen()
    for l in L:
        if l[1].fen() == board_fen:
            return (True, l[4])
    return (False, "")
def subtree(layers, id):
    keep = [id]
    for layer in layers:
        layer = [l for l in layer if l[4] in keep]
        keep = [l[3] for l in layer]
    return(layers)
                """
# Out:
# 'def unique(L):\n    unique_dict = {}\n    for sublist in L:\n        value = sublist[1].fen()\n        if value not in unique_dict:\n            unique_dict[value] = sublist\n    unique_list = list(unique_dict.values())\n    return unique_list\ndef pruning(moves, width, side):\n    moves = unique(moves)\n    w2 = width//2\n    if len(moves) <= width:\n        return moves\n    else:\n        moves.sort(key=lambda l: l[2], reverse=side)\n        p = moves[:w2]\n        rest = moves[w2:]\n        l = len(rest)\n        rate = np.exp(np.log(0.05)/l)\n        weights = [rate ** i for i in range(l)]\n        random_elements = random.choices(rest, weights=weights, k=width - w2)\n        new = p + random_elements\n        new = unique(new)\n        new.sort(key=lambda l: l[2], reverse=side)\n        return(new)\ndef score_move(b, eval_board):\n    moves = list(b.legal_moves)\n    if len(moves) ==0:\n        return[chess.Move.null(), eval_board(b)]\n    else :\n        scored_moves = []\n        for move in moves:\n            copy = b.copy()\n            copy.push(move)\n            scored_moves.append([copy, eval_board(copy)])\n    return(scored_move)\ndef best_move(b,evalboard, side):\n    scored_moves = score_move(b, eval_board)\n    if side:\n        return(max(scored_moves, key=lambda x: x[1]))\n    else:\n        return(min(scored_moves, key=lambda x: x[1]))\n\ndef is_board_in_list(board, L):\n    board_fen = board.fen()\n    for l in L:\n        if l[1].fen() == board_fen:\n            return (True, l[4])\n    return (False, "")\ndef subtree(layers, id):\n    keep = [id]\n    for layer in layers:\n        layer = [l for l in layer if l[4] in keep]\n        keep = [l[3] for l in layer]\n    return(layers)\n                '

# %%
print([1,1,1][:-1])
# Out:
# [1, 1]
